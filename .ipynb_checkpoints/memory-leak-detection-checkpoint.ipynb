# %%
from os import listdir
from os.path import isfile, join

data_path = "data"

data_filenames = [f for f in listdir(data_path) if isfile(join(data_path, f))]
data_filenames.sort()

for i in range(len(data_filenames)):
    print(f"[{i}] - {data_filenames[i]}")
# Out:
# [0] - containerCPUin-memory-analytics-large.csv
# [1] - containerCPUlatest-basic-java-sleep1min-leak.csv
# [2] - containerCPUnodejs-basic-fix.csv
# [3] - containerCPUnodejs-basic-leak.csv
# [4] - containerCPUnodejs-gc-test-leak.csv
# [5] - containerCPUnodejs-gc-test-leakfix.csv
# [6] - containerCPUnoodejs-event-emitter-leak.csv
# [7] - containerCPUnoodejs-event-emitter-leakfix.csv
# [8] - containerCPUscript-basic-java-sleep1min-leak.csv
# [9] - containerCPUscript-basic-java-sleep1min-leakfix.csv
# [10] - containerCPUscript-basic-python-sleep1min-verified-leak.csv
# [11] - containerCPUscript-basic-python-sleep1min-verified-leakfix.csv
# [12] - containerCPUscript-java-hashmap-leak.csv
# [13] - containerCPUscript-java-inflater-concMarkandSweep-leak.csv
# [14] - containerCPUscript-java-inflater-g1-leak.csv
# [15] - containerCPUscript-java-inflater-serialGC-leak.csv
# [16] - containerCPUscript-java-memory-consuming-object-leak.csv
# [17] - containerCPUscript-java-static-member-leak.csv
# [18] - containerCPUscript-java-weak-references-leak.csv
# [19] - containerCPUscript-javaleak-leak.csv
# [20] - containerCPUscript-js-globalvar-leak.csv
# [21] - containerCPUscript-js-recursiveclosure-leak.csv
# [22] - containerCPUscript-mem-alloc-cffi-leak-try3.csv
# [23] - containerCPUscript-mem-alloc-cffi-leakfix.csv
# [24] - containerCPUscript-nodejs-buffer-arr-push-app-regular.csv
# [25] - containerCPUscript-nodejs-buffer-base64-to-obj-regular.csv
# [26] - containerCPUscript-nodejs-buffer-concat-arr-regular.csv
# [27] - containerCPUscript-nodejs-buffer-concat-buf-regular.csv
# [28] - containerCPUscript-nodejs-buffer-offset-insert-regular.csv
# [29] - containerCPUscript-nodejs-buffer-to-obj-regular.csv
# [30] - containerCPUscript-nodejs-sizedbuf-offset-insert-regular.csv
# [31] - containerMemin-memory-analytics-large.csv
# [32] - containerMemlatest-basic-java-sleep1min-leak.csv
# [33] - containerMemnodejs-basic-fix.csv
# [34] - containerMemnodejs-basic-leak.csv
# [35] - containerMemnodejs-gc-test-leak.csv
# [36] - containerMemnodejs-gc-test-leakfix.csv
# [37] - containerMemnoodejs-event-emitter-leak.csv
# [38] - containerMemnoodejs-event-emitter-leakfix.csv
# [39] - containerMemscript-basic-java-sleep1min-leak.csv
# [40] - containerMemscript-basic-java-sleep1min-leakfix.csv
# [41] - containerMemscript-basic-python-sleep1min-verified-leak.csv
# [42] - containerMemscript-basic-python-sleep1min-verified-leakfix.csv
# [43] - containerMemscript-java-hashmap-leak.csv
# [44] - containerMemscript-java-inflater-concMarkandSweep-leak.csv
# [45] - containerMemscript-java-inflater-g1-leak.csv
# [46] - containerMemscript-java-inflater-serialGC-leak.csv
# [47] - containerMemscript-java-memory-consuming-object-leak.csv
# [48] - containerMemscript-java-static-member-leak.csv
# [49] - containerMemscript-java-weak-references-leak.csv
# [50] - containerMemscript-javaleak-leak.csv
# [51] - containerMemscript-js-globalvar-leak.csv
# [52] - containerMemscript-js-recursiveclosure-leak.csv
# [53] - containerMemscript-mem-alloc-cffi-leak-try3.csv
# [54] - containerMemscript-mem-alloc-cffi-leakfix.csv
# [55] - containerMemscript-nodejs-buffer-arr-push-app-regular.csv
# [56] - containerMemscript-nodejs-buffer-base64-to-obj-regular.csv
# [57] - containerMemscript-nodejs-buffer-concat-arr-regular.csv
# [58] - containerMemscript-nodejs-buffer-concat-buf-regular.csv
# [59] - containerMemscript-nodejs-buffer-offset-insert-regular.csv
# [60] - containerMemscript-nodejs-buffer-to-obj-regular.csv
# [61] - containerMemscript-nodejs-sizedbuf-offset-insert-regular.csv
# [62] - hostCPUin-memory-analytics-large.csv
# [63] - hostCPUlatest-basic-java-sleep1min-leak.csv
# [64] - hostCPUnodejs-basic-fix.csv
# [65] - hostCPUnodejs-basic-leak.csv
# [66] - hostCPUnodejs-gc-test-leak.csv
# [67] - hostCPUnodejs-gc-test-leakfix.csv
# [68] - hostCPUnoodejs-event-emitter-leak.csv
# [69] - hostCPUnoodejs-event-emitter-leakfix.csv
# [70] - hostCPUscript-basic-java-sleep1min-leak.csv
# [71] - hostCPUscript-basic-java-sleep1min-leakfix.csv
# [72] - hostCPUscript-basic-python-sleep1min-verified-leak.csv
# [73] - hostCPUscript-basic-python-sleep1min-verified-leakfix.csv
# [74] - hostCPUscript-java-hashmap-leak.csv
# [75] - hostCPUscript-java-inflater-concMarkandSweep-leak.csv
# [76] - hostCPUscript-java-inflater-g1-leak.csv
# [77] - hostCPUscript-java-inflater-serialGC-leak.csv
# [78] - hostCPUscript-java-memory-consuming-object-leak.csv
# [79] - hostCPUscript-java-static-member-leak.csv
# [80] - hostCPUscript-java-weak-references-leak.csv
# [81] - hostCPUscript-javaleak-leak.csv
# [82] - hostCPUscript-js-globalvar-leak.csv
# [83] - hostCPUscript-js-recursiveclosure-leak.csv
# [84] - hostCPUscript-mem-alloc-cffi-leak-try3.csv
# [85] - hostCPUscript-mem-alloc-cffi-leakfix.csv
# [86] - hostCPUscript-nodejs-buffer-arr-push-app-regular.csv
# [87] - hostCPUscript-nodejs-buffer-base64-to-obj-regular.csv
# [88] - hostCPUscript-nodejs-buffer-concat-arr-regular.csv
# [89] - hostCPUscript-nodejs-buffer-concat-buf-regular.csv
# [90] - hostCPUscript-nodejs-buffer-offset-insert-regular.csv
# [91] - hostCPUscript-nodejs-buffer-to-obj-regular.csv
# [92] - hostCPUscript-nodejs-sizedbuf-offset-insert-regular.csv
# [93] - hostMemin-memory-analytics-large.csv
# [94] - hostMemlatest-basic-java-sleep1min-leak.csv
# [95] - hostMemnodejs-basic-fix.csv
# [96] - hostMemnodejs-basic-leak.csv
# [97] - hostMemnodejs-gc-test-leak.csv
# [98] - hostMemnodejs-gc-test-leakfix.csv
# [99] - hostMemnoodejs-event-emitter-leak.csv
# [100] - hostMemnoodejs-event-emitter-leakfix.csv
# [101] - hostMemscript-basic-java-sleep1min-leak.csv
# [102] - hostMemscript-basic-java-sleep1min-leakfix.csv
# [103] - hostMemscript-basic-python-sleep1min-verified-leak.csv
# [104] - hostMemscript-basic-python-sleep1min-verified-leakfix.csv
# [105] - hostMemscript-java-hashmap-leak.csv
# [106] - hostMemscript-java-inflater-concMarkandSweep-leak.csv
# [107] - hostMemscript-java-inflater-g1-leak.csv
# [108] - hostMemscript-java-inflater-serialGC-leak.csv
# [109] - hostMemscript-java-memory-consuming-object-leak.csv
# [110] - hostMemscript-java-static-member-leak.csv
# [111] - hostMemscript-java-weak-references-leak.csv
# [112] - hostMemscript-javaleak-leak.csv
# [113] - hostMemscript-js-globalvar-leak.csv
# [114] - hostMemscript-js-recursiveclosure-leak.csv
# [115] - hostMemscript-mem-alloc-cffi-leak-try3.csv
# [116] - hostMemscript-mem-alloc-cffi-leakfix.csv
# [117] - hostMemscript-nodejs-buffer-arr-push-app-regular.csv
# [118] - hostMemscript-nodejs-buffer-base64-to-obj-regular.csv
# [119] - hostMemscript-nodejs-buffer-concat-arr-regular.csv
# [120] - hostMemscript-nodejs-buffer-concat-buf-regular.csv
# [121] - hostMemscript-nodejs-buffer-offset-insert-regular.csv
# [122] - hostMemscript-nodejs-buffer-to-obj-regular.csv
# [123] - hostMemscript-nodejs-sizedbuf-offset-insert-regular.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
for fn in data_filenames:
    df_temp = pd.read_csv(join(data_path, fn))
    
    if 'time' in df_temp.columns and 'percentage' in df_temp.columns:
        print(fn)
#         figure = plt.figure()
#         ax = plt.gca()
#         ax.plot(df_temp["time"], df_temp["percentage"])
        
#         plt.show()
#         plt.rcParams['figure.figsize'] = [15, 10]
#         plt.plot(df_temp["time"], df_temp["percentage"])
# Out:
# containerCPUin-memory-analytics-large.csv
# containerCPUlatest-basic-java-sleep1min-leak.csv
# containerCPUnodejs-basic-fix.csv
# containerCPUnodejs-basic-leak.csv
# containerCPUnodejs-gc-test-leak.csv
# containerCPUnodejs-gc-test-leakfix.csv
# containerCPUnoodejs-event-emitter-leak.csv
# containerCPUnoodejs-event-emitter-leakfix.csv
# containerCPUscript-basic-java-sleep1min-leak.csv
# containerCPUscript-basic-java-sleep1min-leakfix.csv
# containerCPUscript-basic-python-sleep1min-verified-leak.csv
# containerCPUscript-basic-python-sleep1min-verified-leakfix.csv
# containerCPUscript-java-hashmap-leak.csv
# containerCPUscript-java-inflater-concMarkandSweep-leak.csv
# containerCPUscript-java-inflater-g1-leak.csv
# containerCPUscript-java-inflater-serialGC-leak.csv
# containerCPUscript-java-memory-consuming-object-leak.csv
# containerCPUscript-java-static-member-leak.csv
# containerCPUscript-java-weak-references-leak.csv
# containerCPUscript-javaleak-leak.csv
# containerCPUscript-js-globalvar-leak.csv
# containerCPUscript-js-recursiveclosure-leak.csv
# containerCPUscript-mem-alloc-cffi-leak-try3.csv
# containerCPUscript-mem-alloc-cffi-leakfix.csv
# containerCPUscript-nodejs-buffer-arr-push-app-regular.csv
# containerCPUscript-nodejs-buffer-base64-to-obj-regular.csv
# containerCPUscript-nodejs-buffer-concat-arr-regular.csv
# containerCPUscript-nodejs-buffer-concat-buf-regular.csv
# containerCPUscript-nodejs-buffer-offset-insert-regular.csv
# containerCPUscript-nodejs-buffer-to-obj-regular.csv
# containerCPUscript-nodejs-sizedbuf-offset-insert-regular.csv
# hostCPUin-memory-analytics-large.csv
# hostCPUlatest-basic-java-sleep1min-leak.csv
# hostCPUnodejs-basic-fix.csv
# hostCPUnodejs-basic-leak.csv
# hostCPUnodejs-gc-test-leak.csv
# hostCPUnodejs-gc-test-leakfix.csv
# hostCPUnoodejs-event-emitter-leak.csv
# hostCPUnoodejs-event-emitter-leakfix.csv
# hostCPUscript-basic-java-sleep1min-leak.csv
# hostCPUscript-basic-java-sleep1min-leakfix.csv
# hostCPUscript-basic-python-sleep1min-verified-leak.csv
# hostCPUscript-basic-python-sleep1min-verified-leakfix.csv
# hostCPUscript-java-hashmap-leak.csv
# hostCPUscript-java-inflater-concMarkandSweep-leak.csv
# hostCPUscript-java-inflater-g1-leak.csv
# hostCPUscript-java-inflater-serialGC-leak.csv
# hostCPUscript-java-memory-consuming-object-leak.csv
# hostCPUscript-java-static-member-leak.csv
# hostCPUscript-java-weak-references-leak.csv
# hostCPUscript-javaleak-leak.csv
# hostCPUscript-js-globalvar-leak.csv
# hostCPUscript-js-recursiveclosure-leak.csv
# hostCPUscript-mem-alloc-cffi-leak-try3.csv
# hostCPUscript-mem-alloc-cffi-leakfix.csv
# hostCPUscript-nodejs-buffer-arr-push-app-regular.csv
# hostCPUscript-nodejs-buffer-base64-to-obj-regular.csv
# hostCPUscript-nodejs-buffer-concat-arr-regular.csv
# hostCPUscript-nodejs-buffer-concat-buf-regular.csv
# hostCPUscript-nodejs-buffer-offset-insert-regular.csv
# hostCPUscript-nodejs-buffer-to-obj-regular.csv
# hostCPUscript-nodejs-sizedbuf-offset-insert-regular.csv

# %%
df = pd.read_csv(join(data_path, data_filenames[74]))

df.head()
# Out:
#                       time  percentage
# 0  2019-08-06 05:33:28.299       54.60
# 1  2019-08-06 05:33:38.299       53.45
# 2  2019-08-06 05:33:48.299       52.50
# 3  2019-08-06 05:33:58.299       52.45
# 4  2019-08-06 05:34:08.299       52.75

# %%
len(df)
# Out:
# 1086

# %%
plt.rcParams['figure.figsize'] = [15, 10]
plt.plot(df["time"], df["percentage"])

# %%
df = pd.read_csv("sample-no-leak-1.csv")

df.head()
# Out:
#    Unnamed: 0  time  percentage
# 0           1    32      14.325
# 1           3    35      14.325
# 2           4    37      14.525
# 3           5    40      14.525
# 4           6    42      14.725

# %%
len(df)
# Out:
# 243

# %%
ax = plt.gca()
ax.set_ylim([0, 100])
ax.plot(df["time"], df["percentage"])

# %%
from sklearn import linear_model
from sklearn.metrics import r2_score

# %%
def linear_backward_regression(df):
    anomaly = [0 for i in range(len(df))]
    
    window_size = 100
    critical_time = 100
    r_min = 0.8
    max_util = 100
    
    i = 2
    while i <= len(df) and i <= window_size:
        timestamps = df[-i:]
        
        model = linear_model.LinearRegression()
        model.fit(timestamps[["time"]], timestamps["percentage"])
        
        coef = model.coef_
        intercept = model.intercept_
        
        time_to_max_util = (max_util - intercept) / coef
        time_needed = time_to_max_util - df.loc[[len(df) - 1]]["time"].astype(float)
        
        predicted_value = model.predict(timestamps[["time"]])
        true_value = timestamps["percentage"]
        
        r2 = r2_score(true_value, predicted_value)
        
        r_valid = r2 >= r_min
        time_valid = time_needed <= critical_time
        
        if r_valid & time_valid.get(key=len(df) - 1):
            anomaly[-i:] = [1] * i
        
        i += 1
    
    return anomaly

# %%
anomaly = [0 for i in range(len(df))]
anomaly[-100:] = [1] * 100

# %%
anomaly = linear_backward_regression(df)

# %%
df["anomaly"] = anomaly
df.head()
# Out:
#    Unnamed: 0  time  percentage  anomaly
# 0           1    32      14.325        0
# 1           3    35      14.325        0
# 2           4    37      14.525        0
# 3           5    40      14.525        0
# 4           6    42      14.725        0

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
fig.subplots_adjust(bottom=0.2, right=0.85)

newax = fig.add_axes(ax.get_position())
newax.patch.set_visible(False)

newax.yaxis.set_label_position('right')
newax.yaxis.set_ticks_position('right')

newax.spines['bottom'].set_position(('outward', 35))

ax.plot(df["time"], df["percentage"], 'r-')
ax.set_xlabel('Time', color='red')
ax.set_ylabel('Percentage', color='red')
ax.set_ylim([0, 100])

newax.yaxis.set_visible(False)
newax.xaxis.set_visible(False)

newax.plot(df["time"], df["anomaly"], 'white')
newax.fill_between(df["time"], df["anomaly"], 'green', alpha=0.5)

plt.show()
